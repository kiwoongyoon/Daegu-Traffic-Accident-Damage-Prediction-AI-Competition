# %%
# !pip install pandas==1.4.1
# !pip install antlr4-python3-runtime==4.9.2  
# !pip install xgboost
import pandas as pd
import numpy as np
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:6                                                                                    │
# │                                                                                                  │
# │   3 # !pip install xgboost                                                                       │
# │   4 import pandas as pd                                                                          │
# │   5 import numpy as np                                                                           │
# │ ❱ 6 from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor                    │
# │   7                                                                                              │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/__init__.py:29 in     │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   26                                                                                             │
# │   27 from .dataset import TimeSeriesDataFrame                                                    │
# │   28 from .evaluator import TimeSeriesEvaluator                                                  │
# │ ❱ 29 from .predictor import TimeSeriesPredictor                                                  │
# │   30                                                                                             │
# │   31 _add_stream_handler()                                                                       │
# │   32                                                                                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/predictor.py:17 in    │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    14 from autogluon.timeseries import __version__ as current_ag_version                         │
# │    15 from autogluon.timeseries.configs import TIMESERIES_PRESETS_CONFIGS                        │
# │    16 from autogluon.timeseries.dataset.ts_dataframe import ITEMID, TIMESTAMP, TimeSeriesDataF   │
# │ ❱  17 from autogluon.timeseries.learner import AbstractLearner, TimeSeriesLearner                │
# │    18 from autogluon.timeseries.trainer import AbstractTimeSeriesTrainer                         │
# │    19 from autogluon.timeseries.utils.random import set_random_seed                              │
# │    20                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/learner.py:13 in      │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    10 from autogluon.timeseries.evaluator import TimeSeriesEvaluator                             │
# │    11 from autogluon.timeseries.models.abstract import AbstractTimeSeriesModel                   │
# │    12 from autogluon.timeseries.splitter import AbstractTimeSeriesSplitter, LastWindowSplitter   │
# │ ❱  13 from autogluon.timeseries.trainer import AbstractTimeSeriesTrainer, AutoTimeSeriesTraine   │
# │    14 from autogluon.timeseries.utils.features import TimeSeriesFeatureGenerator                 │
# │    15 from autogluon.timeseries.utils.forecast import get_forecast_horizon_index_ts_dataframe    │
# │    16                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/trainer/__init__.py:1 │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │ ❱ 1 from .abstract_trainer import AbstractTimeSeriesTrainer                                      │
# │   2 from .auto_trainer import AutoTimeSeriesTrainer                                              │
# │   3                                                                                              │
# │   4 __all__ = ["AbstractTimeSeriesTrainer", "AutoTimeSeriesTrainer"]                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/trainer/abstract_trai │
# │ ner.py:23 in <module>                                                                            │
# │                                                                                                  │
# │     20 from autogluon.core.utils.savers import save_json, save_pkl                               │
# │     21 from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesEvaluator                 │
# │     22 from autogluon.timeseries.models.abstract import AbstractTimeSeriesModel                  │
# │ ❱   23 from autogluon.timeseries.models.ensemble import AbstractTimeSeriesEnsembleModel, TimeSe  │
# │     24 from autogluon.timeseries.models.presets import contains_searchspace                      │
# │     25 from autogluon.timeseries.utils.features import CovariateMetadata                         │
# │     26 from autogluon.timeseries.utils.warning_filters import disable_tqdm                       │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/models/__init__.py:2  │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │    1 from .autogluon_tabular import DirectTabularModel, RecursiveTabularModel                    │
# │ ❱  2 from .gluonts import DeepARModel, DLinearModel, PatchTSTModel, SimpleFeedForwardModel, T    │
# │    3 from .local import (                                                                        │
# │    4 │   ARIMAModel,                                                                             │
# │    5 │   AutoARIMAModel,                                                                         │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/models/gluonts/__init │
# │ __.py:1 in <module>                                                                              │
# │                                                                                                  │
# │ ❱  1 from .torch import DeepARModel, DLinearModel, PatchTSTModel, SimpleFeedForwardModel, Tem    │
# │    2                                                                                             │
# │    3 __all__ = [                                                                                 │
# │    4 │   "DeepARModel",                                                                          │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/models/gluonts/torch/ │
# │ __init__.py:1 in <module>                                                                        │
# │                                                                                                  │
# │ ❱  1 from .models import DeepARModel, DLinearModel, PatchTSTModel, SimpleFeedForwardModel, Te    │
# │    2                                                                                             │
# │    3 __all__ = [                                                                                 │
# │    4 │   "DeepARModel",                                                                          │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/autogluon/timeseries/models/gluonts/torch/ │
# │ models.py:15 in <module>                                                                         │
# │                                                                                                  │
# │    12 import torch                                                                               │
# │    13 from gluonts.core.component import from_hyperparameters                                    │
# │    14 from gluonts.model.forecast import QuantileForecast                                        │
# │ ❱  15 from gluonts.torch.model.d_linear import DLinearEstimator                                  │
# │    16 from gluonts.torch.model.deepar import DeepAREstimator                                     │
# │    17 from gluonts.torch.model.estimator import PyTorchLightningEstimator as GluonTSPyTorchLig   │
# │    18 from gluonts.torch.model.forecast import DistributionForecast                              │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/gluonts/torch/model/d_linear/__init__.py:1 │
# │ 4 in <module>                                                                                    │
# │                                                                                                  │
# │   11 # express or implied. See the License for the specific language governing                   │
# │   12 # permissions and limitations under the License.                                            │
# │   13                                                                                             │
# │ ❱ 14 from .module import DLinearModel                                                            │
# │   15 from .lightning_module import DLinearLightningModule                                        │
# │   16 from .estimator import DLinearEstimator                                                     │
# │   17                                                                                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/gluonts/torch/model/d_linear/module.py:21  │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │    18                                                                                            │
# │    19 from gluonts.core.component import validated                                               │
# │    20 from gluonts.model import Input, InputSpec                                                 │
# │ ❱  21 from gluonts.torch.distributions import StudentTOutput                                     │
# │    22 from gluonts.torch.scaler import StdScaler, MeanScaler, NOPScaler                          │
# │    23 from gluonts.torch.model.simple_feedforward import make_linear_layer                       │
# │    24                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/gluonts/torch/__init__.py:23 in <module>   │
# │                                                                                                  │
# │   20 │   "TemporalFusionTransformerEstimator",                                                   │
# │   21 ]                                                                                           │
# │   22 import torch                                                                                │
# │ ❱ 23 from .model.estimator import PyTorchLightningEstimator                                      │
# │   24 from .model.predictor import PyTorchPredictor                                               │
# │   25 from .model.deep_npts import DeepNPTSEstimator                                              │
# │   26 from .model.deepar import DeepAREstimator                                                   │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/gluonts/torch/model/estimator.py:18 in     │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    15 import logging                                                                             │
# │    16                                                                                            │
# │    17 import numpy as np                                                                         │
# │ ❱  18 import pytorch_lightning as pl                                                             │
# │    19 import torch.nn as nn                                                                      │
# │    20                                                                                            │
# │    21 from gluonts.core.component import validated                                               │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/__init__.py:35 in        │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   32 │   _logger.propagate = False                                                               │
# │   33                                                                                             │
# │   34 from lightning_fabric.utilities.seed import seed_everything  # noqa: E402                   │
# │ ❱ 35 from pytorch_lightning.callbacks import Callback  # noqa: E402                              │
# │   36 from pytorch_lightning.core import LightningDataModule, LightningModule  # noqa: E402       │
# │   37 from pytorch_lightning.trainer import Trainer  # noqa: E402                                 │
# │   38                                                                                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/callbacks/__init__.py:28 │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │   25 from pytorch_lightning.callbacks.model_summary import ModelSummary                          │
# │   26 from pytorch_lightning.callbacks.prediction_writer import BasePredictionWriter              │
# │   27 from pytorch_lightning.callbacks.progress import ProgressBarBase, RichProgressBar, TQDMP    │
# │ ❱ 28 from pytorch_lightning.callbacks.pruning import ModelPruning                                │
# │   29 from pytorch_lightning.callbacks.quantization import QuantizationAwareTraining              │
# │   30 from pytorch_lightning.callbacks.rich_model_summary import RichModelSummary                 │
# │   31 from pytorch_lightning.callbacks.stochastic_weight_avg import StochasticWeightAveraging     │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/callbacks/pruning.py:31  │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │    28                                                                                            │
# │    29 import pytorch_lightning as pl                                                             │
# │    30 from pytorch_lightning.callbacks.callback import Callback                                  │
# │ ❱  31 from pytorch_lightning.core.module import LightningModule                                  │
# │    32 from pytorch_lightning.utilities.exceptions import MisconfigurationException               │
# │    33 from pytorch_lightning.utilities.rank_zero import rank_zero_debug, rank_zero_only          │
# │    34                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/core/__init__.py:15 in   │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   12 # See the License for the specific language governing permissions and                       │
# │   13 # limitations under the License.                                                            │
# │   14                                                                                             │
# │ ❱ 15 from pytorch_lightning.core.datamodule import LightningDataModule                           │
# │   16 from pytorch_lightning.core.module import LightningModule                                   │
# │   17                                                                                             │
# │   18 __all__ = ["LightningDataModule", "LightningModule"]                                        │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/core/datamodule.py:25 in │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    22 import pytorch_lightning as pl                                                             │
# │    23 from lightning_fabric.utilities.types import _PATH                                         │
# │    24 from pytorch_lightning.core.hooks import DataHooks                                         │
# │ ❱  25 from pytorch_lightning.core.mixins import HyperparametersMixin                             │
# │    26 from pytorch_lightning.core.saving import _load_from_checkpoint                            │
# │    27 from pytorch_lightning.utilities.argparse import (                                         │
# │    28 │   add_argparse_args,                                                                     │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/core/mixins/__init__.py: │
# │ 16 in <module>                                                                                   │
# │                                                                                                  │
# │   13 # limitations under the License.                                                            │
# │   14                                                                                             │
# │   15 from lightning_fabric.utilities.device_dtype_mixin import _DeviceDtypeModuleMixin  # noq    │
# │ ❱ 16 from pytorch_lightning.core.mixins.hparams_mixin import HyperparametersMixin  # noqa: F4    │
# │   17                                                                                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/core/mixins/hparams_mixi │
# │ n.py:20 in <module>                                                                              │
# │                                                                                                  │
# │    17 from argparse import Namespace                                                             │
# │    18 from typing import Any, List, MutableMapping, Optional, Sequence, Union                    │
# │    19                                                                                            │
# │ ❱  20 from pytorch_lightning.core.saving import ALLOWED_CONFIG_TYPES, PRIMITIVE_TYPES            │
# │    21 from pytorch_lightning.utilities.parsing import AttributeDict, save_hyperparameters        │
# │    22                                                                                            │
# │    23                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/pytorch_lightning/core/saving.py:46 in     │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    43 ALLOWED_CONFIG_TYPES = (AttributeDict, MutableMapping, Namespace)                          │
# │    44                                                                                            │
# │    45 if _OMEGACONF_AVAILABLE:                                                                   │
# │ ❱  46 │   from omegaconf import OmegaConf                                                        │
# │    47 │   from omegaconf.dictconfig import DictConfig                                            │
# │    48 │   from omegaconf.errors import UnsupportedValueType, ValidationError                     │
# │    49                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/__init__.py:1 in <module>        │
# │                                                                                                  │
# │ ❱  1 from .base import Container, DictKeyType, Node, SCMode, UnionNode                           │
# │    2 from .dictconfig import DictConfig                                                          │
# │    3 from .errors import (                                                                       │
# │    4 │   KeyValidationError,                                                                     │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/base.py:11 in <module>           │
# │                                                                                                  │
# │     8                                                                                            │
# │     9 from antlr4 import ParserRuleContext                                                       │
# │    10                                                                                            │
# │ ❱  11 from ._utils import (                                                                      │
# │    12 │   _DEFAULT_MARKER_,                                                                      │
# │    13 │   NoneType,                                                                              │
# │    14 │   ValueKind,                                                                             │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/_utils.py:34 in <module>         │
# │                                                                                                  │
# │     31 │   OmegaConfBaseException,                                                               │
# │     32 │   ValidationError,                                                                      │
# │     33 )                                                                                         │
# │ ❱   34 from .grammar_parser import SIMPLE_INTERPOLATION_PATTERN, parse                           │
# │     35                                                                                           │
# │     36 try:                                                                                      │
# │     37 │   import dataclasses                                                                    │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/grammar_parser.py:12 in <module> │
# │                                                                                                  │
# │     9                                                                                            │
# │    10 # Import from visitor in order to check the presence of generated grammar files            │
# │    11 # files in a single place.                                                                 │
# │ ❱  12 from .grammar_visitor import (  # type: ignore                                             │
# │    13 │   OmegaConfGrammarLexer,                                                                 │
# │    14 │   OmegaConfGrammarParser,                                                                │
# │    15 )                                                                                          │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/grammar_visitor.py:25 in         │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    22 │   from .base import Node  # noqa F401                                                    │
# │    23                                                                                            │
# │    24 try:                                                                                       │
# │ ❱  25 │   from omegaconf.grammar.gen.OmegaConfGrammarLexer import OmegaConfGrammarLexer          │
# │    26 │   from omegaconf.grammar.gen.OmegaConfGrammarParser import OmegaConfGrammarParser        │
# │    27 │   from omegaconf.grammar.gen.OmegaConfGrammarParserVisitor import (                      │
# │    28 │   │   OmegaConfGrammarParserVisitor,                                                     │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/grammar/gen/OmegaConfGrammarLexe │
# │ r.py:257 in <module>                                                                             │
# │                                                                                                  │
# │   254 │   │   return buf.getvalue()                                                              │
# │   255                                                                                            │
# │   256                                                                                            │
# │ ❱ 257 class OmegaConfGrammarLexer(Lexer):                                                        │
# │   258 │                                                                                          │
# │   259 │   atn = ATNDeserializer().deserialize(serializedATN())                                   │
# │   260                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/omegaconf/grammar/gen/OmegaConfGrammarLexe │
# │ r.py:259 in OmegaConfGrammarLexer                                                                │
# │                                                                                                  │
# │   256                                                                                            │
# │   257 class OmegaConfGrammarLexer(Lexer):                                                        │
# │   258 │                                                                                          │
# │ ❱ 259 │   atn = ATNDeserializer().deserialize(serializedATN())                                   │
# │   260 │                                                                                          │
# │   261 │   decisionsToDFA = [ DFA(ds, i) for i, ds in enumerate(atn.decisionToState) ]            │
# │   262                                                                                            │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/antlr4/atn/ATNDeserializer.py:28 in        │
# │ deserialize                                                                                      │
# │                                                                                                  │
# │    25 │   def deserialize(self, data : int):                                                     │
# │    26 │   │   self.data = data                                                                   │
# │    27 │   │   self.pos = 0                                                                       │
# │ ❱  28 │   │   self.checkVersion()                                                                │
# │    29 │   │   atn = self.readATN()                                                               │
# │    30 │   │   self.readStates(atn)                                                               │
# │    31 │   │   self.readRules(atn)                                                                │
# │                                                                                                  │
# │ /home/kiwoongyoon/.local/lib/python3.10/site-packages/antlr4/atn/ATNDeserializer.py:50 in        │
# │ checkVersion                                                                                     │
# │                                                                                                  │
# │    47 │   def checkVersion(self):                                                                │
# │    48 │   │   version = self.readInt()                                                           │
# │    49 │   │   if version != SERIALIZED_VERSION:                                                  │
# │ ❱  50 │   │   │   raise Exception("Could not deserialize ATN with version " + str(version) + "   │
# │    51 │                                                                                          │
# │    52 │   def readATN(self):                                                                     │
# │    53 │   │   idx = self.readInt()                                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# Exception: Could not deserialize ATN with version  (expected 4).

# %%
print( pd.__version__ )
# Out:
# 2.1.3

# %%
train_df = pd.read_csv('../../DATA/train.csv')
# test_df = pd.read_csv('test.csv')[['ID','timestamp']]

# %%
train_df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)
# 0              0.0
# 1              0.0
# 2           1728.0
# 3           1408.0
# 4           1250.0
# ...            ...
# 59392        468.0
# 59393        531.0
# 59394        574.0
# 59395        523.0
# 59396        529.0
#
# [59397 rows x 7 columns]

# %%
data = TimeSeriesDataFrame(train_df.drop(columns=['ID']))
predictor = TimeSeriesPredictor( 
    prediction_length=28,
    target="price(원/kg)",
    eval_metric="RMSE",
)
# seed 고정
predictor.fit( data, random_seed=42, )
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 data = TimeSeriesDataFrame(train_df.drop(columns=['ID']))                                    │
# │   2 predictor = TimeSeriesPredictor(                                                             │
# │   3 │   prediction_length=28,                                                                    │
# │   4 │   target="price(원/kg)",                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'TimeSeriesDataFrame' is not defined

# %%
predictor.refit_full()
# Out:
# 	WARNING: refit_full functionality for TimeSeriesPredictor is experimental and is not yet supported by all models.
# Refitting models via `refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix '_FULL' and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `fit` call.
# Fitting model: Naive_FULL | Skipping fit via cloning parent ...
# Fitting model: SeasonalNaive_FULL | Skipping fit via cloning parent ...
# Fitting model: Theta_FULL | Skipping fit via cloning parent ...
# Fitting model: AutoETS_FULL | Skipping fit via cloning parent ...
# Fitting model: RecursiveTabular_FULL
# 	2.19    s     = Training runtime
# Fitting model: DeepAR_FULL | Skipping fit via cloning parent ...
# Fitting model: WeightedEnsemble_FULL | Skipping fit via cloning parent ...
# Refit complete. Models trained: ['Naive_FULL', 'SeasonalNaive_FULL', 'Theta_FULL', 'AutoETS_FULL', 'RecursiveTabular_FULL', 'DeepAR_FULL', 'WeightedEnsemble_FULL']
# Total runtime: 2.40 s
# Updated best model to 'WeightedEnsemble_FULL' (Previously 'WeightedEnsemble'). AutoGluon will default to using 'WeightedEnsemble_FULL' for predict().
# {'Naive': 'Naive_FULL',
#  'SeasonalNaive': 'SeasonalNaive_FULL',
#  'Theta': 'Theta_FULL',
#  'AutoETS': 'AutoETS_FULL',
#  'RecursiveTabular': 'RecursiveTabular_FULL',
#  'DeepAR': 'DeepAR_FULL',
#  'WeightedEnsemble': 'WeightedEnsemble_FULL'}

# %%
# seed 고정
pred = predictor.predict(data, random_seed=42, )
# Out:
# Global seed set to 42
# Model not specified in predict, will default to the model with the best validation score: WeightedEnsemble_FULL

# %%
pred
# Out:
#                            mean          0.1          0.2          0.3  \
# item_id timestamp
# TG_A_J  2023-03-04  3249.371428  1061.962512  1822.099598  2356.666160
#         2023-03-05   685.749831 -2060.506732 -1122.077911  -447.970651
#         2023-03-06  3044.917527  -480.330324   808.741333  1657.877709
#         2023-03-07  3463.382329  -435.830595   925.919328  1858.888452
#         2023-03-08  3304.855823  -856.234747   587.264285  1612.549541
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   502.113238  -220.864280    57.778526   225.951939
#         2023-03-28   521.814296  -230.533786    68.465458   238.048419
#         2023-03-29   519.017230  -272.460916    47.440414   233.578369
#         2023-03-30   506.832145  -264.524065    37.183076   226.988193
#         2023-03-31   511.823768  -297.308532    18.280521   213.199803
#
#                             0.4          0.5          0.6          0.7  \
# item_id timestamp
# TG_A_J  2023-03-04  2831.553078  3274.046010  3707.234661  4172.362595
#         2023-03-05   117.590776   638.844024  1181.768701  1752.230389
#         2023-03-06  2397.617743  3046.794298  3698.106493  4405.636461
#         2023-03-07  2645.802365  3413.735307  4185.687008  4994.269255
#         2023-03-08  2489.554600  3296.153781  4110.799357  5002.118203
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   373.761455   506.834047   632.832728   771.448217
#         2023-03-28   386.681816   528.159235   671.685615   814.718084
#         2023-03-29   384.538602   531.467662   668.278763   818.807452
#         2023-03-30   372.222564   509.844633   647.372533   796.298493
#         2023-03-31   368.650540   511.401207   659.188667   818.049213
#
#                             0.8          0.9
# item_id timestamp
# TG_A_J  2023-03-04  4714.482384  5514.882444
#         2023-03-05  2428.259075  3363.004906
#         2023-03-06  5237.350182  6492.382986
#         2023-03-07  5956.045761  7290.270292
#         2023-03-08  6032.298060  7480.064991
# ...                         ...          ...
# RD_F_J  2023-03-27   938.181708  1187.946035
#         2023-03-28   983.599501  1224.211551
#         2023-03-29   992.982668  1232.181649
#         2023-03-30   969.568536  1215.261210
#         2023-03-31   992.375615  1230.679636
#
# [1092 rows x 10 columns]

# %%
submission = pd.read_csv('./sample_submission.csv')
submission['answer'] = pred.reset_index()['mean']
submission.loc[ submission['answer'] < 0.0, 'answer'] = 0.0
submission.to_csv('./dacon_submission.csv', index=False)
submission
# Out:
#                    ID       answer
# 0     TG_A_J_20230304  3249.371428
# 1     TG_A_J_20230305   685.749831
# 2     TG_A_J_20230306  3044.917527
# 3     TG_A_J_20230307  3463.382329
# 4     TG_A_J_20230308  3304.855823
# ...               ...          ...
# 1087  RD_F_J_20230327   502.113238
# 1088  RD_F_J_20230328   521.814296
# 1089  RD_F_J_20230329   519.017230
# 1090  RD_F_J_20230330   506.832145
# 1091  RD_F_J_20230331   511.823768
#
# [1092 rows x 2 columns]
