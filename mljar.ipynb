# %% [markdown]
# ## Import

# %%
import os
import random
import numpy as np
import pandas as pd
from datetime import datetime
from holidays import country_holidays
from xgboost import XGBRegressor 
import xgboost as xgb 
from tqdm import tqdm

import optuna 
from optuna.samplers import TPESampler

from supervised.automl import AutoML

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.impute import KNNImputer
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder
from sklearn import base
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings(action='ignore') 

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('../../DATA/train.csv')
test_df  = pd.read_csv('../../DATA/test.csv')

# %%
test_df.head(30)
[9,9,10,10,10,10,10,10,10,11,11,11,11,11,11,11,12,12,12,12,12,12,12,13,13,13,13,13]
# Out:
#                  ID  timestamp item corp loc  year  month  day  weekday  \
# 0   TG_A_J_20230304 2023-03-04   TG    A   J  2023      3    4        5
# 1   TG_A_J_20230305 2023-03-05   TG    A   J  2023      3    5        6
# 2   TG_A_J_20230306 2023-03-06   TG    A   J  2023      3    6        0
# 3   TG_A_J_20230307 2023-03-07   TG    A   J  2023      3    7        1
# 4   TG_A_J_20230308 2023-03-08   TG    A   J  2023      3    8        2
# 5   TG_A_J_20230309 2023-03-09   TG    A   J  2023      3    9        3
# 6   TG_A_J_20230310 2023-03-10   TG    A   J  2023      3   10        4
# 7   TG_A_J_20230311 2023-03-11   TG    A   J  2023      3   11        5
# 8   TG_A_J_20230312 2023-03-12   TG    A   J  2023      3   12        6
# 9   TG_A_J_20230313 2023-03-13   TG    A   J  2023      3   13        0
# 10  TG_A_J_20230314 2023-03-14   TG    A   J  2023      3   14        1
# 11  TG_A_J_20230315 2023-03-15   TG    A   J  2023      3   15        2
# 12  TG_A_J_20230316 2023-03-16   TG    A   J  2023      3   16        3
# 13  TG_A_J_20230317 2023-03-17   TG    A   J  2023      3   17        4
# 14  TG_A_J_20230318 2023-03-18   TG    A   J  2023      3   18        5
# 15  TG_A_J_20230319 2023-03-19   TG    A   J  2023      3   19        6
# 16  TG_A_J_20230320 2023-03-20   TG    A   J  2023      3   20        0
# 17  TG_A_J_20230321 2023-03-21   TG    A   J  2023      3   21        1
# 18  TG_A_J_20230322 2023-03-22   TG    A   J  2023      3   22        2
# 19  TG_A_J_20230323 2023-03-23   TG    A   J  2023      3   23        3
# 20  TG_A_J_20230324 2023-03-24   TG    A   J  2023      3   24        4
# 21  TG_A_J_20230325 2023-03-25   TG    A   J  2023      3   25        5
# 22  TG_A_J_20230326 2023-03-26   TG    A   J  2023      3   26        6
# 23  TG_A_J_20230327 2023-03-27   TG    A   J  2023      3   27        0
# 24  TG_A_J_20230328 2023-03-28   TG    A   J  2023      3   28        1
# 25  TG_A_J_20230329 2023-03-29   TG    A   J  2023      3   29        2
# 26  TG_A_J_20230330 2023-03-30   TG    A   J  2023      3   30        3
# 27  TG_A_J_20230331 2023-03-31   TG    A   J  2023      3   31        4
# 28  TG_A_S_20230304 2023-03-04   TG    A   S  2023      3    4        5
# 29  TG_A_S_20230305 2023-03-05   TG    A   S  2023      3    5        6
#
#     weekofyear  dayofyear  season  weekend
# 0            9         63       1        0
# 1            9         64       1        1
# 2           10         65       1        0
# 3           10         66       1        0
# 4           10         67       1        0
# 5           10         68       1        0
# 6           10         69       1        0
# 7           10         70       1        0
# 8           10         71       1        1
# 9           11         72       1        0
# 10          11         73       1        0
# 11          11         74       1        0
# 12          11         75       1        0
# 13          11         76       1        0
# 14          11         77       1        0
# 15          11         78       1        1
# 16          12         79       1        0
# 17          12         80       1        0
# 18          12         81       1        0
# 19          12         82       1        0
# 20          12         83       1        0
# 21          12         84       1        0
# 22          12         85       1        1
# 23          13         86       1        0
# 24          13         87       1        0
# 25          13         88       1        0
# 26          13         89       1        0
# 27          13         90       1        0
# 28           9         63       1        0
# 29           9         64       1        1

# %% [markdown]
# ## Make Date Data

# %%
# 데이터 타입 변경, 열 이름 변경 

new_column_names = {
    'corporation': 'corp',
    'location': 'loc',
    'supply(kg)': 'supply',
    'price(원/kg)': 'price',
}
train_df = train_df.rename(columns=new_column_names)
test_df = test_df.rename(columns=new_column_names)
train_df['timestamp']  = pd.to_datetime(train_df['timestamp'])
test_df['timestamp']  = pd.to_datetime(test_df['timestamp'])

# %%
train_df['item_id'] = train_df.ID.str[:6 ]
train_df
# Out:
#                     ID  timestamp item corp loc    supply   price item_id
# 0      TG_A_J_20190101 2019-01-01   TG    A   J       0.0     0.0  TG_A_J
# 1      TG_A_J_20190102 2019-01-02   TG    A   J       0.0     0.0  TG_A_J
# 2      TG_A_J_20190103 2019-01-03   TG    A   J   60601.0  1728.0  TG_A_J
# 3      TG_A_J_20190104 2019-01-04   TG    A   J   25000.0  1408.0  TG_A_J
# 4      TG_A_J_20190105 2019-01-05   TG    A   J   32352.0  1250.0  TG_A_J
# ...                ...        ...  ...  ...  ..       ...     ...     ...
# 59392  RD_F_J_20230227 2023-02-27   RD    F   J  452440.0   468.0  RD_F_J
# 59393  RD_F_J_20230228 2023-02-28   RD    F   J  421980.0   531.0  RD_F_J
# 59394  RD_F_J_20230301 2023-03-01   RD    F   J  382980.0   574.0  RD_F_J
# 59395  RD_F_J_20230302 2023-03-02   RD    F   J  477220.0   523.0  RD_F_J
# 59396  RD_F_J_20230303 2023-03-03   RD    F   J  427520.0   529.0  RD_F_J
#
# [59397 rows x 8 columns]

# %%
domains = train_df[['item_id', 'item' ,'corp', 'loc']].drop_duplicates().reset_index(drop=True)
(domains)
# Out:
#    item_id item corp loc
# 0   TG_A_J   TG    A   J
# 1   TG_A_S   TG    A   S
# 2   TG_B_J   TG    B   J
# 3   TG_B_S   TG    B   S
# 4   TG_C_J   TG    C   J
# 5   TG_C_S   TG    C   S
# 6   TG_D_J   TG    D   J
# 7   TG_D_S   TG    D   S
# 8   TG_E_J   TG    E   J
# 9   TG_E_S   TG    E   S
# 10  CR_A_J   CR    A   J
# 11  CR_B_J   CR    B   J
# 12  CR_C_J   CR    C   J
# 13  CR_D_J   CR    D   J
# 14  CR_D_S   CR    D   S
# 15  CR_E_J   CR    E   J
# 16  CR_E_S   CR    E   S
# 17  CB_A_J   CB    A   J
# 18  CB_A_S   CB    A   S
# 19  CB_D_J   CB    D   J
# 20  CB_E_J   CB    E   J
# 21  RD_A_J   RD    A   J
# 22  RD_A_S   RD    A   S
# 23  RD_C_S   RD    C   S
# 24  RD_D_J   RD    D   J
# 25  RD_D_S   RD    D   S
# 26  RD_E_J   RD    E   J
# 27  RD_E_S   RD    E   S
# 28  BC_A_J   BC    A   J
# 29  BC_A_S   BC    A   S
# 30  BC_B_J   BC    B   J
# 31  BC_B_S   BC    B   S
# 32  BC_C_J   BC    C   J
# 33  BC_C_S   BC    C   S
# 34  BC_D_J   BC    D   J
# 35  BC_E_J   BC    E   J
# 36  BC_E_S   BC    E   S
# 37  CB_F_J   CB    F   J
# 38  RD_F_J   RD    F   J

# %%
def get_date_info(data) :
    # data의 날짜 정보 추출하기 
    data['year'] = data['timestamp'].dt.year
    data['month'] = data['timestamp'].dt.month
    data['day'] = data['timestamp'].dt.day
    data['weekday'] = data['timestamp'].dt.weekday
    data['weekofyear'] = data['timestamp'].dt.isocalendar().week
    data['dayofyear'] = data['timestamp'].dt.dayofyear #해당 년도의 몇 일째 

def month_to_season(month):
    if month in [12, 1, 2]:
        return 0
    elif month in [3, 4, 5]:
        return 1
    elif month in [6, 7, 8]:
        return 2
    else:
        return 3

    
get_date_info(train_df)
get_date_info(test_df)

# 'month' 칼럼을 정수형으로 변환
train_df['season'] = train_df['month'].astype(int).apply(month_to_season)
test_df['season'] = test_df['month'].astype(int).apply(month_to_season)
test_df['weekend'] = test_df['weekday'].apply(lambda x : 1 if x==6  else 0 )

# %%
#known_covariates_names=["weekend", 'year', 'month', 'day', 'weekday', 'weekofyear', 'dayofyear' , 'season' ]
train_df_nodomain = train_df.drop(columns=['item', 'corp','item_id'])
train_df_nodomain
# Out:
#                     ID  timestamp loc    supply   price  year  month  day  \
# 0      TG_A_J_20190101 2019-01-01   J       0.0     0.0  2019      1    1
# 1      TG_A_J_20190102 2019-01-02   J       0.0     0.0  2019      1    2
# 2      TG_A_J_20190103 2019-01-03   J   60601.0  1728.0  2019      1    3
# 3      TG_A_J_20190104 2019-01-04   J   25000.0  1408.0  2019      1    4
# 4      TG_A_J_20190105 2019-01-05   J   32352.0  1250.0  2019      1    5
# ...                ...        ...  ..       ...     ...   ...    ...  ...
# 59392  RD_F_J_20230227 2023-02-27   J  452440.0   468.0  2023      2   27
# 59393  RD_F_J_20230228 2023-02-28   J  421980.0   531.0  2023      2   28
# 59394  RD_F_J_20230301 2023-03-01   J  382980.0   574.0  2023      3    1
# 59395  RD_F_J_20230302 2023-03-02   J  477220.0   523.0  2023      3    2
# 59396  RD_F_J_20230303 2023-03-03   J  427520.0   529.0  2023      3    3
#
#        weekday  weekofyear  dayofyear  season
# 0            1           1          1       0
# 1            2           1          2       0
# 2            3           1          3       0
# 3            4           1          4       0
# 4            5           1          5       0
# ...        ...         ...        ...     ...
# 59392        0           9         58       0
# 59393        1           9         59       0
# 59394        2           9         60       1
# 59395        3           9         61       1
# 59396        4           9         62       1
#
# [59397 rows x 12 columns]

# %%
train_df_nodomain['weekend'] = train_df_nodomain['weekday'].apply(lambda x : 1 if x == 6 else 0)
train_df_nodomain
# Out:
#                     ID  timestamp loc    supply   price  year  month  day  \
# 0      TG_A_J_20190101 2019-01-01   J       0.0     0.0  2019      1    1
# 1      TG_A_J_20190102 2019-01-02   J       0.0     0.0  2019      1    2
# 2      TG_A_J_20190103 2019-01-03   J   60601.0  1728.0  2019      1    3
# 3      TG_A_J_20190104 2019-01-04   J   25000.0  1408.0  2019      1    4
# 4      TG_A_J_20190105 2019-01-05   J   32352.0  1250.0  2019      1    5
# ...                ...        ...  ..       ...     ...   ...    ...  ...
# 59392  RD_F_J_20230227 2023-02-27   J  452440.0   468.0  2023      2   27
# 59393  RD_F_J_20230228 2023-02-28   J  421980.0   531.0  2023      2   28
# 59394  RD_F_J_20230301 2023-03-01   J  382980.0   574.0  2023      3    1
# 59395  RD_F_J_20230302 2023-03-02   J  477220.0   523.0  2023      3    2
# 59396  RD_F_J_20230303 2023-03-03   J  427520.0   529.0  2023      3    3
#
#        weekday  weekofyear  dayofyear  season  weekend
# 0            1           1          1       0        0
# 1            2           1          2       0        0
# 2            3           1          3       0        0
# 3            4           1          4       0        0
# 4            5           1          5       0        0
# ...        ...         ...        ...     ...      ...
# 59392        0           9         58       0        0
# 59393        1           9         59       0        0
# 59394        2           9         60       1        0
# 59395        3           9         61       1        0
# 59396        4           9         62       1        0
#
# [59397 rows x 13 columns]

# %%
# 휴일 정보 추가하니 성능 더 하락 

years  = [2019,2020,2021,2022,2023 ]
holi_dates=[]
for year in years :
    holidayarr = country_holidays('KR', years = year).items()
    for day in holidayarr:
        holi_dates.append(day[0])
    
print(holi_dates[0])

train_df['holi'] = train_df['timestamp'].apply(lambda x: int(x in holi_dates))
test_df['holi'] = test_df['timestamp'].apply(lambda x: int(x in holi_dates))
train_df.loc[(train_df['holi'] == 0) & (train_df['weekday'] >= 6), 'holi'] = 1
test_df.loc[(train_df['holi'] == 0) & (test_df['weekday'] >= 6), 'holi'] = 1
# Out:
# 2019-01-01

# %%
def trans_fourier(data) :
    #날짜
    data['sin_date'] = -np.sin(2 * np.pi * (data['month']+data['day']/31)/12)
    data['cos_date'] = -np.cos(2 * np.pi * (data['month']+data['day']/31)/12)

    #월
    data['sin_month'] = -np.sin(2 * np.pi * data['month']/12.0)
    data['cos_month'] = -np.cos(2 * np.pi * data['month']/12.0)
    
    data['sin_week'] = -np.sin(2 * np.pi * (data['weekofyear'])/52.0)
    data['cos_week'] = -np.cos(2 * np.pi * (data['weekofyear'])/52.0)

    #요일
    data['sin_dayofweek'] = -np.sin(2 * np.pi * (data['weekday']+1)/7.0)
    data['cos_dayofweek'] = -np.cos(2 * np.pi * (data['weekday']+1)/7.0)
    
    
trans_fourier(train_df)
trans_fourier(test_df)

# %% [markdown]
# # Supply Data , New feature

# %%
# 아이템, 유통회사, 지역 묶기 
def new_columns(data):
    data['item_corp_loc']= data['item'].astype(str).str.cat([data['corp'].astype(str), data['loc'].astype(str)], sep='')
    # data['item_corp']= data['item'].astype(str).str.cat([data['corp'].astype(str)], sep='')
    data['item_loc']= data['item'].astype(str).str.cat([data['loc'].astype(str)], sep='')
    data['item_loc'] =data['item_loc'].astype(str) 
    # data['item_corp'] = data['item_corp'].astype(str)
    data['item_corp_loc']= data['item_corp_loc'].astype(str)
    
    data['y_it_loc_m'] = data['item'].str.cat([data['loc'], data['year'].astype(str),data['month'].astype(str)], sep = '')

new_columns(train_df)
new_columns(test_df)

# %%
def fill_supply(train, test, start, end):
    train['timestamp'] = pd.to_datetime(train['timestamp'])  
    start_date = pd.to_datetime(start)
    end_date = pd.to_datetime(end)
    mask = (train['timestamp'] >= start_date) & (train['timestamp'] <= end_date)
    filtered_train_df = train.loc[mask]

    result = filtered_train_df.groupby('item_corp_loc')['supply'].median()
    result = result.reset_index().rename(columns={'supply': 'supply'})

    test['supply'] = 0 
    test = test.set_index('item_corp_loc')
    test.update(result.set_index('item_corp_loc'))
    test = test.reset_index()

    return test 

test_df = fill_supply(train_df, test_df, "2023-02-01","2023-03-03")

# %% [markdown]
# # Imputaion Of Data

# %% [markdown]
# # Encoding Categorical Features

# %%
class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):
   
    def __init__(self,colnames,targetName,
                  n_fold=5, verbosity=True,
                  discardOriginal_col=False):
        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
        
    def fit(self, X, y=None):
        return self
    
    def transform(self,X):        
        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)       
        
        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold,
                   shuffle = True)        
        col_mean_name = self.colnames + '_' + 'encod'
        X[col_mean_name] = np.nan       
        
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
            X[col_mean_name].fillna(mean_of_target, inplace = True)  
            
        if self.verbosity:            
            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,self.targetName,                                                                                    np.corrcoef(X[self.targetName].values,encoded_feature)[0][1]))

        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
        return X

# %%
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    def __init__(self,train,colNames,encodedName):
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        mean = self.train[[self.colNames,
        self.encodedName]].groupby(
        self.colNames).mean().reset_index()
        dd = {}
        for row in (mean.itertuples(index=False)):
            dd[row[0]] = row[1]
            X[self.encodedName] = X[self.colNames]
            X[self.encodedName] = X[self.encodedName].map(dd.get)
        return X

# %%
for col in ['item_corp_loc', 'item_loc' ,'item' ,'corp', 'loc' ,'season','y_it_loc_m']:
    t_encoder = KFoldTargetEncoderTrain(colnames=col , targetName='price',n_fold=5)
    train_df  = t_encoder.fit_transform(train_df)
    
    newcolname = f'{col}_encod'
    
    test_t_encoder = KFoldTargetEncoderTest(train_df, colNames=col , encodedName=newcolname)
    test_df = test_t_encoder.transform(test_df)
# Out:
# Correlation between the new feature, item_corp_loc_encod and, price is 0.6327969090540054.
# Correlation between the new feature, item_loc_encod and, price is 0.6139308527488362.
# Correlation between the new feature, item_encod and, price is 0.6078361845777633.
# Correlation between the new feature, corp_encod and, price is 0.14528901419694895.
# Correlation between the new feature, loc_encod and, price is 0.040619659711968695.
# Correlation between the new feature, season_encod and, price is 0.14288003987389114.
# Correlation between the new feature, y_it_loc_m_encod and, price is 0.7579636381602503.

# %%
test_df
# Out:
#      item_corp_loc               ID  timestamp item corp loc  year  month  \
# 0             TGAJ  TG_A_J_20230304 2023-03-04   TG    A   J  2023      3
# 1             TGAJ  TG_A_J_20230305 2023-03-05   TG    A   J  2023      3
# 2             TGAJ  TG_A_J_20230306 2023-03-06   TG    A   J  2023      3
# 3             TGAJ  TG_A_J_20230307 2023-03-07   TG    A   J  2023      3
# 4             TGAJ  TG_A_J_20230308 2023-03-08   TG    A   J  2023      3
# ...            ...              ...        ...  ...  ...  ..   ...    ...
# 1087          RDFJ  RD_F_J_20230327 2023-03-27   RD    F   J  2023      3
# 1088          RDFJ  RD_F_J_20230328 2023-03-28   RD    F   J  2023      3
# 1089          RDFJ  RD_F_J_20230329 2023-03-29   RD    F   J  2023      3
# 1090          RDFJ  RD_F_J_20230330 2023-03-30   RD    F   J  2023      3
# 1091          RDFJ  RD_F_J_20230331 2023-03-31   RD    F   J  2023      3
#
#       day  weekday  ...  item_loc  y_it_loc_m    supply  item_corp_loc_encod  \
# 0       4        5  ...       TGJ    TGJ20233   10094.8          2567.187865
# 1       5        6  ...       TGJ    TGJ20233   10094.8          2567.187865
# 2       6        0  ...       TGJ    TGJ20233   10094.8          2567.187865
# 3       7        1  ...       TGJ    TGJ20233   10094.8          2567.187865
# 4       8        2  ...       TGJ    TGJ20233   10094.8          2567.187865
# ...   ...      ...  ...       ...         ...       ...                  ...
# 1087   27        0  ...       RDJ    RDJ20233  425040.0           259.681858
# 1088   28        1  ...       RDJ    RDJ20233  425040.0           259.681858
# 1089   29        2  ...       RDJ    RDJ20233  425040.0           259.681858
# 1090   30        3  ...       RDJ    RDJ20233  425040.0           259.681858
# 1091   31        4  ...       RDJ    RDJ20233  425040.0           259.681858
#
#       item_loc_encod   item_encod   corp_encod    loc_encod  season_encod  \
# 0        3006.697432  3177.328604  1141.662687  1062.335718   1531.249461
# 1        3006.697432  3177.328604  1141.662687  1062.335718   1531.249461
# 2        3006.697432  3177.328604  1141.662687  1062.335718   1531.249461
# 3        3006.697432  3177.328604  1141.662687  1062.335718   1531.249461
# 4        3006.697432  3177.328604  1141.662687  1062.335718   1531.249461
# ...              ...          ...          ...          ...           ...
# 1087      252.011007   187.077466   259.133976  1062.335718   1531.249461
# 1088      252.011007   187.077466   259.133976  1062.335718   1531.249461
# 1089      252.011007   187.077466   259.133976  1062.335718   1531.249461
# 1090      252.011007   187.077466   259.133976  1062.335718   1531.249461
# 1091      252.011007   187.077466   259.133976  1062.335718   1531.249461
#
#       y_it_loc_m_encod
# 0          2580.009091
# 1          2580.009091
# 2          2580.009091
# 3          2580.009091
# 4          2580.009091
# ...                ...
# 1087        476.089610
# 1088        476.089610
# 1089        476.089610
# 1090        476.089610
# 1091        476.089610
#
# [1092 rows x 32 columns]

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corp', 'loc']

def encode_cols_v1(data,data2, cat_name , target , weight) :
    mean = data[target].mean()
    agg = data.groupby(cat_name)[target].agg(['count','mean'])
    counts =agg['count']
    means  =agg['mean']
    
    smooth = (counts*means + weight*mean)/ (counts+weight)
    data[cat_name] = data[cat_name].map(smooth) 
    data2[cat_name] = data2[cat_name].map(smooth)
    
    return data, data2 
    


for i in qual_col:= -1,total_time_limit=

# %%
# scaler로 스케일링 해주기

# %%
train_df.columns
# Out:
# Index(['ID', 'timestamp', 'item', 'corp', 'loc', 'supply', 'price', 'year',
#        'month', 'day', 'weekday', 'weekofyear', 'dayofyear', 'season', 'holi',
#        'sin_date', 'cos_date', 'sin_month', 'cos_month', 'sin_week',
#        'cos_week', 'sin_dayofweek', 'cos_dayofweek', 'item_corp_loc',
#        'item_loc', 'y_it_loc_m', 'item_corp_loc_encod', 'item_loc_encod',
#        'item_encod', 'corp_encod', 'loc_encod', 'season_encod',
#        'y_it_loc_m_encod'],
#       dtype='object')

# %%
train_df #item', 'corp', 'loc''item_corp_loc',       'item_loc', 'y_it_loc_m',
# Out:
#                     ID  timestamp item corp loc    supply   price  year  \
# 0      TG_A_J_20190101 2019-01-01   TG    A   J       0.0     0.0  2019
# 1      TG_A_J_20190102 2019-01-02   TG    A   J       0.0     0.0  2019
# 2      TG_A_J_20190103 2019-01-03   TG    A   J   60601.0  1728.0  2019
# 3      TG_A_J_20190104 2019-01-04   TG    A   J   25000.0  1408.0  2019
# 4      TG_A_J_20190105 2019-01-05   TG    A   J   32352.0  1250.0  2019
# ...                ...        ...  ...  ...  ..       ...     ...   ...
# 59392  RD_F_J_20230227 2023-02-27   RD    F   J  452440.0   468.0  2023
# 59393  RD_F_J_20230228 2023-02-28   RD    F   J  421980.0   531.0  2023
# 59394  RD_F_J_20230301 2023-03-01   RD    F   J  382980.0   574.0  2023
# 59395  RD_F_J_20230302 2023-03-02   RD    F   J  477220.0   523.0  2023
# 59396  RD_F_J_20230303 2023-03-03   RD    F   J  427520.0   529.0  2023
#
#        month  day  ...  item_corp_loc  item_loc  y_it_loc_m  \
# 0          1    1  ...           TGAJ       TGJ    TGJ20191
# 1          1    2  ...           TGAJ       TGJ    TGJ20191
# 2          1    3  ...           TGAJ       TGJ    TGJ20191
# 3          1    4  ...           TGAJ       TGJ    TGJ20191
# 4          1    5  ...           TGAJ       TGJ    TGJ20191
# ...      ...  ...  ...            ...       ...         ...
# 59392      2   27  ...           RDFJ       RDJ    RDJ20232
# 59393      2   28  ...           RDFJ       RDJ    RDJ20232
# 59394      3    1  ...           RDFJ       RDJ    RDJ20233
# 59395      3    2  ...           RDFJ       RDJ    RDJ20233
# 59396      3    3  ...           RDFJ       RDJ    RDJ20233
#
#       item_corp_loc_encod  item_loc_encod   item_encod   corp_encod  \
# 0             2633.087276     3012.818407  3178.322804  1126.735991
# 1             2633.087276     3016.098201  3178.322804  1137.849658
# 2             2633.087276     3012.818407  3166.733146  1137.849658
# 3             2592.570502     2997.932320  3178.322804  1156.972594
# 4             2490.053719     3016.098201  3166.733146  1148.000642
# ...                   ...             ...          ...          ...
# 59392          257.356220      253.231214   187.368302   257.593344
# 59393          268.434709      252.056015   187.368302   258.532312
# 59394          253.277461      252.056015   189.714844   258.532312
# 59395          257.356220      252.056015   189.714844   258.532312
# 59396          253.277461      254.803055   189.714844   259.191255
#
#          loc_encod  season_encod  y_it_loc_m_encod
# 0      1065.404933    995.909264       1375.545455
# 1      1065.404933    995.909264       1375.545455
# 2      1062.415837    995.909264       1353.169492
# 3      1056.587411    995.909264       1353.169492
# 4      1065.404933    982.853998       1375.545455
# ...            ...           ...               ...
# 59392  1064.215911    982.853998        404.445652
# 59393  1063.117546    982.853998        345.195652
# 59394  1064.215911   1547.448354        442.750000
# 59395  1056.587411   1547.448354        442.750000
# 59396  1056.587411   1523.418053        501.571429
#
# [59397 rows x 33 columns]

# %%
#학습에 사용하지 않을 변수들을 제거합니다
train_x = train_df.drop(columns=['ID','season', 'timestamp', 'price', 'day', 'month', 'weekday','item', 'corp', 'loc','item_corp_loc', 'item_loc', 'y_it_loc_m',])
train_y = train_df['price']
test_x = test_df.drop(columns=['ID', 'season','timestamp' ,  'day', 'month', 'weekday', 'item', 'corp', 'loc','item_corp_loc',   'item_loc', 'y_it_loc_m'])

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59397 entries, 0 to 59396
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   supply               59397 non-null  float64
#  1   year                 59397 non-null  int32
#  2   weekofyear           59397 non-null  UInt32
#  3   dayofyear            59397 non-null  int32
#  4   holi                 59397 non-null  int64
#  5   sin_date             59397 non-null  float64
#  6   cos_date             59397 non-null  float64
#  7   sin_month            59397 non-null  float64
#  8   cos_month            59397 non-null  float64
#  9   sin_week             59397 non-null  Float64
#  10  cos_week             59397 non-null  Float64
#  11  sin_dayofweek        59397 non-null  float64
#  12  cos_dayofweek        59397 non-null  float64
#  13  item_corp_loc_encod  59397 non-null  float64
#  14  item_loc_encod       59397 non-null  float64
#  15  item_encod           59397 non-null  float64
#  16  corp_encod           59397 non-null  float64
#  17  loc_encod            59397 non-null  float64
#  18  season_encod         59397 non-null  float64
#  19  y_it_loc_m_encod     59397 non-null  float64
# dtypes: Float64(2), UInt32(1), float64(14), int32(2), int64(1)
# memory usage: 8.6 MB

# %% [markdown]
# # AutoMl  적용

# %%
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-common 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# autogluon-core 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# autogluon-features 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# autogluon-multimodal 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# autogluon-tabular 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# autogluon-timeseries 0.8.2 requires pandas<1.6,>=1.4.1, but you have pandas 2.1.2 which is incompatible.
# mlflow 1.30.1 requires pandas<2, but you have pandas 2.1.2 which is incompatible.
# pycaret 3.1.0 requires pandas<2.0.0,>=1.3.0, but you have pandas 2.1.2 which is incompatible.
# sktime 0.21.1 requires pandas<2.1.0,>=1.1.0, but you have pandas 2.1.2 which is incompatible.
# ydata-profiling 4.6.0 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.1.2 which is incompatible.
# ydata-profiling 4.6.0 requires typeguard<5,>=4.1.2, but you have typeguard 2.13.3 which is incompatible.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.1.2

# %%
Cross_validation = {
    "validation_type": "kfold",
    "k_folds": 5,
    "shuffle": True,
    "random_seed": 38 #24
}

# %%
total_time_limit = 60*60*4
automl = AutoML(mode="Compete", n_jobs = -1,total_time_limit=total_time_limit, eval_metric="mse", validation_strategy=Cross_validation)
automl.fit(train_x, train_y)
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_5
# The task is regression with evaluation metric mse
# AutoML will use algorithms: ['Decision Tree', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step simple_algorithms will try to check up to 3 models
# 1_DecisionTree mse 505562.121325 trained in 1.39 seconds
# 2_DecisionTree mse 416202.886068 trained in 1.32 seconds
# 3_DecisionTree mse 416202.886068 trained in 1.39 seconds
# * Step default_algorithms will try to check up to 7 models
# 4_Default_LightGBM mse 169879.004731 trained in 6.86 seconds
# 5_Default_Xgboost mse 208797.200515 trained in 8.39 seconds
# There was an error during 6_Default_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 7_Default_NeuralNetwork mse 899127.251302 trained in 13.56 seconds
# 8_Default_RandomForest mse 372873.176826 trained in 3.76 seconds
# 9_Default_ExtraTrees mse 1085613.550623 trained in 5.82 seconds
# There was an error during 10_Default_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# * Step not_so_random will try to check up to 63 models
# 18_LightGBM mse 182951.304008 trained in 6.97 seconds
# 9_Xgboost mse 198951.27963 trained in 8.5 seconds
# There was an error during 27_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 36_RandomForest mse 380548.670663 trained in 8.71 seconds
# 45_ExtraTrees mse 1156171.303189 trained in 3.35 seconds
# 54_NeuralNetwork mse 887652.608502 trained in 13.59 seconds
# There was an error during 63_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 19_LightGBM mse 185156.141376 trained in 3.51 seconds
# 10_Xgboost mse 204166.658508 trained in 7.98 seconds
# There was an error during 28_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 37_RandomForest mse 445276.77389 trained in 6.27 seconds
# 46_ExtraTrees mse 1216570.896217 trained in 2.97 seconds
# 55_NeuralNetwork mse 683958.273563 trained in 35.35 seconds
# There was an error during 64_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 20_LightGBM mse 169141.692809 trained in 5.69 seconds
# 11_Xgboost mse 206925.276317 trained in 9.37 seconds
# There was an error during 29_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 38_RandomForest mse 293897.975584 trained in 5.53 seconds
# 47_ExtraTrees mse 865023.052474 trained in 4.49 seconds
# 56_NeuralNetwork mse 1577023.219642 trained in 22.14 seconds
# There was an error during 65_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 21_LightGBM mse 171084.7686 trained in 6.63 seconds
# 12_Xgboost mse 212971.563505 trained in 5.73 seconds
# There was an error during 30_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 39_RandomForest mse 285329.966127 trained in 5.09 seconds
# 48_ExtraTrees mse 884050.750994 trained in 3.3 seconds
# 57_NeuralNetwork mse 848335.917552 trained in 18.56 seconds
# There was an error during 66_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 22_LightGBM mse 182447.368208 trained in 3.33 seconds
# 13_Xgboost mse 209202.125342 trained in 8.95 seconds
# There was an error during 31_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 40_RandomForest mse 253936.918017 trained in 4.51 seconds
# 49_ExtraTrees mse 819685.939929 trained in 4.78 seconds
# 58_NeuralNetwork mse 709525.713779 trained in 30.45 seconds
# There was an error during 67_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 23_LightGBM mse 173834.308922 trained in 9.14 seconds
# 14_Xgboost mse 227828.033679 trained in 12.44 seconds
# There was an error during 32_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 41_RandomForest mse 262216.328822 trained in 9.18 seconds
# 50_ExtraTrees mse 772776.178568 trained in 4.39 seconds
# 59_NeuralNetwork mse 673837.159705 trained in 30.66 seconds
# There was an error during 68_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 24_LightGBM mse 171429.243793 trained in 6.48 seconds
# 15_Xgboost mse 200233.348417 trained in 7.94 seconds
# There was an error during 33_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 42_RandomForest mse 369592.867274 trained in 5.18 seconds
# 51_ExtraTrees mse 1105041.306985 trained in 4.0 seconds
# 60_NeuralNetwork mse 701177.309367 trained in 19.58 seconds
# There was an error during 69_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 25_LightGBM mse 175328.269598 trained in 5.19 seconds
# 16_Xgboost mse 204802.130422 trained in 7.25 seconds
# There was an error during 34_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 43_RandomForest mse 370808.44365 trained in 4.71 seconds
# 52_ExtraTrees mse 1122084.650682 trained in 3.65 seconds
# 61_NeuralNetwork mse 2245987.056279 trained in 12.6 seconds
# There was an error during 70_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# 26_LightGBM mse 185270.69057 trained in 5.55 seconds
# 17_Xgboost mse 198296.44493 trained in 16.39 seconds
# There was an error during 35_CatBoost training.
# Please check AutoML_5/errors.md for details.
# 44_RandomForest mse 255644.869794 trained in 5.19 seconds
# 53_ExtraTrees mse 862759.045697 trained in 3.77 seconds
# 62_NeuralNetwork mse 926909.013842 trained in 10.65 seconds
# There was an error during 71_NearestNeighbors training.
# Please check AutoML_5/errors.md for details.
# * Step golden_features will try to check up to 3 models
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /home/kiwoongyoon/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# 20_LightGBM_RandomFeature mse 175199.062707 trained in 24.64 seconds
# Drop features ['season_encod', 'random_feature', 'sin_month', 'cos_month']
# * Step features_selection will try to check up to 5 models
# 20_LightGBM_SelectedFeatures mse 168180.609345 trained in 8.46 seconds
# 17_Xgboost_SelectedFeatures mse 196739.934977 trained in 18.3 seconds
# 40_RandomForest_SelectedFeatures mse 256362.997748 trained in 6.74 seconds
# 59_NeuralNetwork_SelectedFeatures mse 641611.803349 trained in 32.01 seconds
# 50_ExtraTrees_SelectedFeatures mse 798971.401699 trained in 4.57 seconds
# * Step hill_climbing_1 will try to check up to 27 models
# 63_LightGBM_SelectedFeatures mse 168158.156343 trained in 9.27 seconds
# 64_LightGBM_SelectedFeatures mse 169841.914583 trained in 8.24 seconds
# 65_LightGBM mse 168371.896714 trained in 9.73 seconds
# 66_LightGBM mse 171702.884686 trained in 7.96 seconds
# 67_LightGBM mse 170772.76234 trained in 10.74 seconds
# 68_LightGBM mse 170471.203322 trained in 10.1 seconds
# 69_Xgboost_SelectedFeatures mse 199057.733569 trained in 15.66 seconds
# 70_Xgboost_SelectedFeatures mse 199097.294865 trained in 18.62 seconds
# 71_Xgboost mse 198836.473137 trained in 20.62 seconds
# 72_Xgboost mse 197627.730679 trained in 22.5 seconds
# 73_Xgboost mse 195857.967346 trained in 316.54 seconds
# 74_RandomForest mse 253226.003528 trained in 5.15 seconds
# 75_RandomForest mse 256698.830944 trained in 6.6 seconds
# 76_RandomForest mse 253258.445914 trained in 14.43 seconds
# 77_RandomForest_SelectedFeatures mse 252845.701075 trained in 14.71 seconds
# 78_RandomForest_SelectedFeatures mse 256443.746073 trained in 14.84 seconds
# 79_DecisionTree mse 416202.886068 trained in 2.75 seconds
# 80_DecisionTree mse 416202.886068 trained in 2.75 seconds
# 81_DecisionTree mse 505562.121325 trained in 2.74 seconds
# 82_NeuralNetwork_SelectedFeatures mse 698533.845339 trained in 45.01 seconds
# 83_NeuralNetwork mse 700801.711087 trained in 43.67 seconds
# 84_NeuralNetwork mse 680934.942135 trained in 51.82 seconds
# 85_NeuralNetwork mse 719034.034474 trained in 855.62 seconds
# 86_ExtraTrees mse 809389.26427 trained in 11.88 seconds
# 87_ExtraTrees_SelectedFeatures mse 740392.057024 trained in 9.95 seconds
# 88_ExtraTrees mse 851447.994429 trained in 10.5 seconds
# 89_ExtraTrees mse 794013.93365 trained in 13.61 seconds
# * Step hill_climbing_2 will try to check up to 18 models
# 90_LightGBM_SelectedFeatures mse 169978.342251 trained in 69.01 seconds
# 91_LightGBM_SelectedFeatures mse 171468.663146 trained in 93.57 seconds
# 92_LightGBM_SelectedFeatures mse 169547.937824 trained in 70.32 seconds
# 93_LightGBM_SelectedFeatures mse 171525.708987 trained in 63.29 seconds
# 94_LightGBM mse 169369.054285 trained in 93.95 seconds
# 95_LightGBM mse 171314.87288 trained in 79.75 seconds
# 96_Xgboost mse 196737.500498 trained in 2467.94 seconds
# 97_Xgboost mse 194641.497482 trained in 11.23 seconds
# 98_Xgboost_SelectedFeatures mse 195072.853879 trained in 15.15 seconds
# 99_Xgboost mse 197961.719404 trained in 1272.22 seconds
# 100_RandomForest_SelectedFeatures mse 283774.567574 trained in 6.17 seconds
# 101_RandomForest mse 283867.277966 trained in 5.82 seconds
# 102_RandomForest mse 282661.808784 trained in 6.05 seconds
# 103_NeuralNetwork_SelectedFeatures mse 792576.850657 trained in 23.07 seconds
# 104_NeuralNetwork mse 816379.252416 trained in 25.13 seconds
# 105_NeuralNetwork mse 914417.95938 trained in 13.33 seconds
# 106_ExtraTrees_SelectedFeatures mse 860826.218669 trained in 5.62 seconds
# 107_ExtraTrees mse 814091.867337 trained in 4.99 seconds
# * Step boost_on_errors will try to check up to 1 model
# 63_LightGBM_SelectedFeatures_BoostOnErrors mse 168305.076087 trained in 10.78 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mse 162740.847892 trained in 11.28 seconds
# * Step stack will try to check up to 49 models
# 63_LightGBM_SelectedFeatures_Stacked mse 171730.416023 trained in 6.5 seconds
# 97_Xgboost_Stacked mse 170696.547522 trained in 9.19 seconds
# 77_RandomForest_SelectedFeatures_Stacked mse 164009.084264 trained in 36.31 seconds
# 59_NeuralNetwork_SelectedFeatures_Stacked mse 5319765.357054 trained in 19.75 seconds
# 87_ExtraTrees_SelectedFeatures_Stacked mse 163400.191945 trained in 15.56 seconds
# 20_LightGBM_SelectedFeatures_Stacked mse 172620.51756 trained in 6.64 seconds
# 98_Xgboost_SelectedFeatures_Stacked mse 168126.168752 trained in 13.33 seconds
# 74_RandomForest_Stacked mse 164026.240237 trained in 23.96 seconds
# 59_NeuralNetwork_Stacked mse 4273350.346821 trained in 22.4 seconds
# 50_ExtraTrees_Stacked mse 163778.699522 trained in 9.67 seconds
# 65_LightGBM_Stacked mse 172191.24765 trained in 6.66 seconds
# 73_Xgboost_Stacked mse 171092.431555 trained in 9.46 seconds
# 76_RandomForest_Stacked mse 164064.902092 trained in 27.21 seconds
# 84_NeuralNetwork_Stacked mse 2690157.376568 trained in 38.58 seconds
# 89_ExtraTrees_Stacked mse 163946.923286 trained in 10.83 seconds
# 20_LightGBM_Stacked mse 171469.193034 trained in 6.83 seconds
# 96_Xgboost_Stacked mse 168748.911929 trained in 10.38 seconds
# 40_RandomForest_Stacked mse 163626.90684 trained in 48.31 seconds
# 55_NeuralNetwork_Stacked mse 1132304.928294 trained in 738.12 seconds
# 50_ExtraTrees_SelectedFeatures_Stacked mse 163813.676714 trained in 26.08 seconds
# 94_LightGBM_Stacked mse 172123.61723 trained in 21.73 seconds
# 17_Xgboost_SelectedFeatures_Stacked mse 167900.155521 trained in 911.63 seconds
# 44_RandomForest_Stacked mse 164528.588392 trained in 32.52 seconds
# 82_NeuralNetwork_SelectedFeatures_Stacked mse 2083436.67497 trained in 35.73 seconds
# 86_ExtraTrees_Stacked mse 163145.098357 trained in 9.82 seconds
# 92_LightGBM_SelectedFeatures_Stacked mse 171287.890418 trained in 6.84 seconds
# 72_Xgboost_Stacked mse 168162.225787 trained in 11.65 seconds
# 40_RandomForest_SelectedFeatures_Stacked mse 164009.530575 trained in 32.53 seconds
# 83_NeuralNetwork_Stacked mse 10166626.329402 trained in 24.71 seconds
# 107_ExtraTrees_Stacked mse 164215.261471 trained in 10.38 seconds
# 64_LightGBM_SelectedFeatures_Stacked mse 171758.528459 trained in 6.98 seconds
# 99_Xgboost_Stacked mse 169649.104398 trained in 9.29 seconds
# 78_RandomForest_SelectedFeatures_Stacked mse 164274.03003 trained in 35.84 seconds
# 60_NeuralNetwork_Stacked mse 3367978.568301 trained in 16.51 seconds
# 49_ExtraTrees_Stacked mse 163836.094019 trained in 10.28 seconds
# 4_Default_LightGBM_Stacked mse 172533.403279 trained in 7.0 seconds
# 17_Xgboost_Stacked mse 168880.635441 trained in 12.59 seconds
# 75_RandomForest_Stacked mse 164511.341676 trained in 35.87 seconds
# 58_NeuralNetwork_Stacked mse 1245742.989509 trained in 44.58 seconds
# 88_ExtraTrees_Stacked mse 163860.473561 trained in 9.94 seconds
# 90_LightGBM_SelectedFeatures_Stacked mse 171812.618501 trained in 6.97 seconds
# 71_Xgboost_Stacked mse 167846.817807 trained in 9.86 seconds
# 41_RandomForest_Stacked mse 163934.994692 trained in 51.13 seconds
# 85_NeuralNetwork_Stacked mse 1475448.289094 trained in 49.45 seconds
# 106_ExtraTrees_SelectedFeatures_Stacked mse 164546.35368 trained in 11.78 seconds
# 9_Xgboost_Stacked mse 171855.496976 trained in 12.97 seconds
# 102_RandomForest_Stacked mse 163989.842081 trained in 20.22 seconds
# 103_NeuralNetwork_SelectedFeatures_Stacked mse 4122777.880676 trained in 19.67 seconds
# 53_ExtraTrees_Stacked mse 164536.898666 trained in 10.6 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mse 161063.824108 trained in 23.47 seconds
# AutoML fit time: 9261.28 seconds
# AutoML best model: Ensemble_Stacked
# AutoML(eval_metric='mse', mode='Compete', total_time_limit=14400,
#        validation_strategy={'k_folds': 5, 'random_seed': 38, 'shuffle': True,
#                             'validation_type': 'kfold'})

# %%
test_x =test_x.reindex(columns=train_x.columns)

# %%
pred = automl.predict(test_x)

# %%
pred
# Out:
# array([2690.12524875, 2397.60277252, 2657.69027763, ...,  572.18713662,
#         570.15458834,  564.0366915 ])

# %%
#Validation : MAE: 729715.7680863414,  Best score: 856.2573364295463,  Best trial: {'lambda': 0.06858310598122817, 'alpha': 0.7713413681986561, 'colsample_bytree': 0.9442346449671033, 'subsample': 0.9750961748574901, 'learning_rate': 0.076433115411846, 'n_estimators': 446, 'max_depth': 8, 'min_child_weight': 16}





model_xgb = RandomForestRegressor(**study.best_trial.params)
kf = KFold(n_splits=5, shuffle=True , random_state=42)

ensemble_predicts= []
scores =[]


for train_idx, val_idx in tqdm(kf.split(train_x), total=5, desc="Processing folds"):
    X_t, X_val = train_x.iloc[train_idx], train_x.iloc[val_idx]
    y_t, y_val = train_y[train_idx], train_y[val_idx]
    
    # 두 모델 모두 학습
    model_xgb.fit(X_t, y_t)
    
    # 각 모델로부터 Validation set에 대한 예측을 평균내어 앙상블 예측 생성
    val_pred = model_xgb.predict(X_val)
    
    # Validation set에 대한 대회 평가 산식 계산 후 저장
    scores.append(mean_squared_error(y_val, val_pred))
    
    # test 데이터셋에 대한 예측 수행 후 저장
    model_xgb_pred = model_xgb.predict(test_x)
    model_xgb_pred = np.where(model_xgb_pred < 0, 0, model_xgb_pred)
    
    ensemble_predicts.append(model_xgb_pred)

# K-fold 모든 예측의 평균을 계산하여 fold별 모델들의 앙상블 예측 생성
final_predictions = np.mean(ensemble_predicts, axis=0)

# 각 fold에서의 Validation Metric Score와 전체 평균 Validation Metric Score출력
print("Validation : MAE scores for each fold:", scores)
print("Validation : MAE:", np.mean(scores))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/kiwoongyoon/바탕화면/DACON/JEJU PRODUCT PRICE PREDICT/CODE/MODELS/xgboost_optuna.ipynb Cell 21 line 7
#       <a href='vscode-notebook-cell:/home/kiwoongyoon/%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/DACON/JEJU%20PRODUCT%20PRICE%20PREDICT/CODE/MODELS/xgboost_optuna.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> #Validation : MAE: 729715.7680863414,  Best score: 856.2573364295463,  Best trial: {'lambda': 0.06858310598122817, 'alpha': 0.7713413681986561, 'colsample_bytree': 0.9442346449671033, 'subsample': 0.9750961748574901, 'learning_rate': 0.076433115411846, 'n_estimators': 446, 'max_depth': 8, 'min_child_weight': 16}
# ----> <a href='vscode-notebook-cell:/home/kiwoongyoon/%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/DACON/JEJU%20PRODUCT%20PRICE%20PREDICT/CODE/MODELS/xgboost_optuna.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> model_xgb = RandomForestRegressor(**study.best_trial.params)
#       <a href='vscode-notebook-cell:/home/kiwoongyoon/%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/DACON/JEJU%20PRODUCT%20PRICE%20PREDICT/CODE/MODELS/xgboost_optuna.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a> kf = KFold(n_splits=5, shuffle=True , random_state=42)
#      <a href='vscode-notebook-cell:/home/kiwoongyoon/%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/DACON/JEJU%20PRODUCT%20PRICE%20PREDICT/CODE/MODELS/xgboost_optuna.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> ensemble_predicts= []
#
# TypeError: RandomForestRegressor.__init__() got an unexpected keyword argument 'lambda'

# %%
#Validation : MAE: 729715.7680863414,  Best score: 856.2573364295463,  Best trial: {'lambda': 0.06858310598122817, 'alpha': 0.7713413681986561, 'colsample_bytree': 0.9442346449671033, 'subsample': 0.9750961748574901, 'learning_rate': 0.076433115411846, 'n_estimators': 446, 'max_depth': 8, 'min_child_weight': 16}

#encod_col_v1 : Validation : MAE: 722972.6923, Best score: 864.4005832556281, Best trial: {'lambda': 0.07246551885960752, 'alpha': 0.5233846374744797, 'colsample_bytree': 0.9008060223667523, 'subsample': 0.9996254959269878, 'learning_rate': 0.061161155234371184, 'n_estimators': 753, 'max_depth': 8, 'min_child_weight': 23}


model_xgb = XGBRegressor(**study.best_trial.params)
kf = KFold(n_splits=5, shuffle=True , random_state=42)

ensemble_predicts= []
scores =[]


for train_idx, val_idx in tqdm(kf.split(train_x), total=5, desc="Processing folds"):
    X_t, X_val = train_x.iloc[train_idx], train_x.iloc[val_idx]
    y_t, y_val = train_y[train_idx], train_y[val_idx]
    
    # 두 모델 모두 학습
    model_xgb.fit(X_t, y_t)
    
    # 각 모델로부터 Validation set에 대한 예측을 평균내어 앙상블 예측 생성
    val_pred = model_xgb.predict(X_val)
    
    # Validation set에 대한 대회 평가 산식 계산 후 저장
    scores.append(mean_squared_error(y_val, val_pred))
    
    # test 데이터셋에 대한 예측 수행 후 저장
    model_xgb_pred = model_xgb.predict(test_x)
    model_xgb_pred = np.where(model_xgb_pred < 0, 0, model_xgb_pred)
    
    ensemble_predicts.append(model_xgb_pred)

# K-fold 모든 예측의 평균을 계산하여 fold별 모델들의 앙상블 예측 생성
final_predictions = np.mean(ensemble_predicts, axis=0)

# 각 fold에서의 Validation Metric Score와 전체 평균 Validation Metric Score출력
print("Validation : MAE scores for each fold:", scores)
print("Validation : MAE:", np.mean(scores))
# Out:
# Processing folds: 100%|██████████| 5/5 [00:33<00:00,  6.63s/it]
# Validation : MAE scores for each fold: [2.7672175331040094, 2.6085926305807012, 2.600025852176349, 2.737986521970589, 2.4819060995110966]
# Validation : MAE: 2.639145727468549

# %% [markdown]
# ## Inference

# %%
final_predictions = np.round(pred, 2)
final_predictions
# Out:
# array([2690.13, 2397.6 , 2657.69, ...,  572.19,  570.15,  564.04])

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('../../DATA/sample_submission.csv')
submission
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
submission['answer'] = final_predictions
submission.loc[submission.index % 7 == 1, 'answer'] = 0

# %%
submission.loc[submission['answer'] <= 0, 'answer'] = 0

# %%
submission.to_csv('../../DATA/SUBMIT/new_automl_sub.csv', index=False)

# %%
sub = pd.read_csv('../../DATA/SUBMIT/automl_sub.csv')
sub.head(20)
# Out:
#                  ID   answer
# 0   TG_A_J_20230304  3414.06
# 1   TG_A_J_20230305     7.18
# 2   TG_A_J_20230306  3680.06
# 3   TG_A_J_20230307  3660.65
# 4   TG_A_J_20230308  3691.81
# 5   TG_A_J_20230309  3720.74
# 6   TG_A_J_20230310  3838.66
# 7   TG_A_J_20230311  3436.29
# 8   TG_A_J_20230312     5.01
# 9   TG_A_J_20230313  3662.43
# 10  TG_A_J_20230314  3652.76
# 11  TG_A_J_20230315  3690.44
# 12  TG_A_J_20230316  3986.16
# 13  TG_A_J_20230317  4581.56
# 14  TG_A_J_20230318  4519.68
# 15  TG_A_J_20230319     8.97
# 16  TG_A_J_20230320  4720.94
# 17  TG_A_J_20230321  4698.87
# 18  TG_A_J_20230322  4828.65
# 19  TG_A_J_20230323  4870.56

# %%
sub.loc[sub.index % 7 == 1, 'answer'] = 0
# Out:
#                  ID   answer
# 0   TG_A_J_20230304  3414.06
# 1   TG_A_J_20230305     0.00
# 2   TG_A_J_20230306  3680.06
# 3   TG_A_J_20230307  3660.65
# 4   TG_A_J_20230308  3691.81
# 5   TG_A_J_20230309  3720.74
# 6   TG_A_J_20230310  3838.66
# 7   TG_A_J_20230311  3436.29
# 8   TG_A_J_20230312     0.00
# 9   TG_A_J_20230313  3662.43
# 10  TG_A_J_20230314  3652.76
# 11  TG_A_J_20230315  3690.44
# 12  TG_A_J_20230316  3986.16
# 13  TG_A_J_20230317  4581.56
# 14  TG_A_J_20230318  4519.68
# 15  TG_A_J_20230319     0.00
# 16  TG_A_J_20230320  4720.94
# 17  TG_A_J_20230321  4698.87
# 18  TG_A_J_20230322  4828.65
# 19  TG_A_J_20230323  4870.56

# %%
sub.to_csv('../../DATA/SUBMIT/sundayzero_automl_sub.csv', index=False)
